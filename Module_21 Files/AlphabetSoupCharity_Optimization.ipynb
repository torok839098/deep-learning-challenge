# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
import sklearn as skl
from tensorflow import keras
from keras.callbacks import ModelCheckpoint
#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %% [markdown]
# To optimize a model there are several strategies, for example:
#
# *   Dropping more or fewer columns.
# *  Creating more bins for rare occurrences in columns.
# *  Increasing or decreasing the number of values for each bin.
# *   Add more neurons to a hidden layer.
# *   Add more hidden layers.
# *   Use different activation functions for the hidden layers.
# *   Add or reduce the number of epochs to the training regimen.
#
# Therefore for the next attempts, I will consider these options:
#
#
# *   First attempt: drop columns
# *   Second attempt Adding more neurons, less layers
# *   Third attempt: Control the number of epochs
# *   Fourth (if time permits): Activation functions + maybe tuning

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df.drop(columns=['EIN', 'NAME'])
# Out:
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS   ASK_AMT  \
# ...

# %%
#From statology
for col in application_df:
  print(application_df[col].unique())
# Out:
# [ 10520599  10531628  10547893 ... 996012607 996015768 996086871]
# ['BLUE KNIGHTS MOTORCYCLE CLUB' 'AMERICAN CHESAPEAKE CLUB CHARITABLE TR'
#  'ST CLOUD PROFESSIONAL FIREFIGHTERS' ...
#  'THE LIONS CLUB OF HONOLULU KAMEHAMEHA'
#  'AMERICAN FEDERATION OF GOVERNMENT EMPLOYEES LOCAL 2886'
#  'WATERHOUSE CHARITABLE TR']
# ['T10' 'T3' 'T5' 'T7' 'T4' 'T6' 'T2' 'T9' 'T19' 'T8' 'T13' 'T12' 'T29'
#  'T25' 'T14' 'T17' 'T15']
# ['Independent' 'CompanySponsored' 'Family/Parent' 'National' 'Regional'
#  'Other']
# ['C1000' 'C2000' 'C3000' 'C1200' 'C2700' 'C7000' 'C7200' 'C1700' 'C4000'
#  'C7100' 'C2800' 'C6000' 'C2100' 'C1238' 'C5000' 'C7120' 'C1800' 'C4100'
#  'C1400' 'C1270' 'C2300' 'C8200' 'C1500' 'C7210' 'C1300' 'C1230' 'C1280'
#  'C1240' 'C2710' 'C2561' 'C1250' 'C8000' 'C1245' 'C1260' 'C1235' 'C1720'
#  'C1257' 'C4500' 'C2400' 'C8210' 'C1600' 'C1278' 'C1237' 'C4120' 'C2170'
#  'C1728' 'C1732' 'C2380' 'C1283' 'C1570' 'C2500' 'C1267' 'C3700' 'C1580'
# ...

# %%
#Other method
application_df.nunique()
# Out:
# EIN                       34299
# NAME                      19568
# APPLICATION_TYPE             17
# AFFILIATION                   6
# CLASSIFICATION               71
# USE_CASE                      5
# ORGANIZATION                  4
# STATUS                        2
# INCOME_AMT                    9
# SPECIAL_CONSIDERATIONS        2
# ASK_AMT                    8747
# IS_SUCCESSFUL                 2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning

Application_TypeCounts=application_df.value_counts('APPLICATION_TYPE')
print(Application_TypeCounts)
# Out:
# APPLICATION_TYPE
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T14        3
# T25        3
# T29        2
# T15        2
# T17        1
# dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace=list (Application_TypeCounts[Application_TypeCounts < 500].index)
print(application_types_to_replace)
# Out:
# ['T9', 'T13', 'T12', 'T2', 'T14', 'T25', 'T29', 'T15', 'T17']

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace=list (Application_TypeCounts[Application_TypeCounts < 500].index)

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
#Look at CLASSIFICATION value counts for binning
Classification_ValueCounts=application_df['CLASSIFICATION'].value_counts()
print(Classification_ValueCounts)
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
Classification_countsRevised=Classification_ValueCounts[Classification_ValueCounts>1]
print(Classification_countsRevised)
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
#classifications_to_replace=list(Classification_countsRevised[Classification_countsRevised < 800].index)
#print(classifications_to_replace)
# Out:
# ['C7000', 'C1700', 'C4000', 'C5000', 'C1270', 'C2700', 'C2800', 'C7100', 'C1300', 'C1280', 'C1230', 'C1400', 'C7200', 'C2300', 'C1240', 'C8000', 'C7120', 'C1500', 'C1800', 'C6000', 'C1250', 'C8200', 'C1238', 'C1278', 'C1235', 'C1237', 'C7210', 'C2400', 'C1720', 'C4100', 'C1257', 'C1600', 'C1260', 'C2710', 'C0', 'C3200', 'C1234', 'C1246', 'C1267', 'C1256']

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`

classifications_to_replace=list(Classification_ValueCounts[Classification_ValueCounts < 1000].index)
 #Replace in dataframe

for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Split our preprocessed data into our features and target arrays
y = application_df['IS_SUCCESSFUL']
X = application_df.drop(columns= ['IS_SUCCESSFUL','EIN','NAME',])

# Preview the data
X[:5]
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590

# %%
y[:5]
# Out:
# 0    1
# 1    1
# 2    0
# 3    1
# 4    1
# Name: IS_SUCCESSFUL, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
X = pd.get_dummies(X)

# %%
#Check features
X.head()
# Out:
#    STATUS  ASK_AMT  APPLICATION_TYPE_Other  APPLICATION_TYPE_T10  \
# 0       1     5000                       0                     1
# 1       1   108590                       0                     0
# 2       1     5000                       0                     0
# 3       1     6692                       0                     0
# 4       1   142590                       0                     0
#
#    APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  APPLICATION_TYPE_T4  \
# 0                     0                    0                    0
# 1                     0                    1                    0
# 2                     0                    0                    0
# 3                     0                    1                    0
# 4                     0                    1                    0
#
#    APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  APPLICATION_TYPE_T7  ...  \
# 0                    0                    0                    0  ...
# ...

# %%
# Split our preprocessed data into our features and target arrays
 # Split the preprocessed data into a training and testing dataset

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
#Get shape of trained features
X_train.shape
# Out:
# (25724, 43)

# %%
#Get shape of test features
X_test.shape
# Out:
# (8575, 43)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %% [markdown]
# First attempt: Deleting extra columns: Display DataFrame,Drop columns, train again

# %%
#Create copy of DataFrame
Optmodel_1=application_df.copy()
Optmodel_1
# Out:
#              EIN                                               NAME  \
# 0       10520599                       BLUE KNIGHTS MOTORCYCLE CLUB
# 1       10531628             AMERICAN CHESAPEAKE CLUB CHARITABLE TR
# 2       10547893                 ST CLOUD PROFESSIONAL FIREFIGHTERS
# 3       10553066                     SOUTHSIDE ATHLETIC ASSOCIATION
# 4       10556103           GENETIC RESEARCH INSTITUTE OF THE DESERT
# ...          ...                                                ...
# 34294  996009318              THE LIONS CLUB OF HONOLULU KAMEHAMEHA
# 34295  996010315           INTERNATIONAL ASSOCIATION OF LIONS CLUBS
# 34296  996012607                                PTA HAWAII CONGRESS
# 34297  996015768  AMERICAN FEDERATION OF GOVERNMENT EMPLOYEES LO...
# 34298  996086871                           WATERHOUSE CHARITABLE TR
#
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# ...

# %%
#Drop additional column
Optmodel_1.drop(columns=['EIN', 'NAME','SPECIAL_CONSIDERATIONS'])
# Out:
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION  STATUS     INCOME_AMT   ASK_AMT  IS_SUCCESSFUL
# ...

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace=list (Application_TypeCounts[Application_TypeCounts < 500].index)

# Replace in dataframe
for app in application_types_to_replace:
   Optmodel_1['APPLICATION_TYPE'] = Optmodel_1['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
Optmodel_1['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`

classifications_to_replace=list(Classification_ValueCounts[Classification_ValueCounts < 1000].index)
 #Replace in dataframe

for cls in classifications_to_replace:
    Optmodel_1['CLASSIFICATION'] = Optmodel_1['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
Optmodel_1['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Split our preprocessed data into our features and target arrays
y = Optmodel_1['IS_SUCCESSFUL']
X = Optmodel_1.drop(columns= ['IS_SUCCESSFUL','EIN','NAME','SPECIAL_CONSIDERATIONS'])

# Preview the data
X[:5]
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT  ASK_AMT
# 0   Association       1              0     5000
# 1  Co-operative       1         1-9999   108590
# 2   Association       1              0     5000
# 3         Trust       1    10000-24999     6692
# 4         Trust       1  100000-499999   142590

# %%
# Convert categorical data to numeric with `pd.get_dummies`
X = pd.get_dummies(X)
#Check features
X.head()
# Out:
#    STATUS  ASK_AMT  APPLICATION_TYPE_Other  APPLICATION_TYPE_T10  \
# 0       1     5000                       0                     1
# 1       1   108590                       0                     0
# 2       1     5000                       0                     0
# 3       1     6692                       0                     0
# 4       1   142590                       0                     0
#
#    APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  APPLICATION_TYPE_T4  \
# 0                     0                    0                    0
# 1                     0                    1                    0
# 2                     0                    0                    0
# 3                     0                    1                    0
# 4                     0                    1                    0
#
#    APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  APPLICATION_TYPE_T7  ...  \
# 0                    0                    0                    0  ...
# ...

# %%
# Split our preprocessed data into our features and target arrays
 # Split the preprocessed data into a training and testing dataset

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
#Get shape of trained features
X_train.shape
#Get shape of test features
X_test.shape
# Out:
# (8575, 41)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
nn = tf.keras.models.Sequential()

# %%
# Removed a column therefore input_dim is different
# First hidden layer
nn.add(tf.keras.layers.Dense(input_dim=41, units=80, activation="relu"))
# Second hidden layer
nn.add(tf.keras.layers.Dense(input_dim=10, units=30, activation="relu"))
# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="linear"))
nn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_6 (Dense)             (None, 80)                3360
#
#  dense_7 (Dense)             (None, 30)                2430
#
#  dense_8 (Dense)             (None, 1)                 31
#
# ...
# Total params: 5821 (22.74 KB)
# Trainable params: 5821 (22.74 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
#Train
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 2s 2ms/step - loss: 1.0226 - accuracy: 0.6758
# Epoch 2/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.7039 - accuracy: 0.7186
# Epoch 3/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.8069 - accuracy: 0.7091
# Epoch 4/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6350 - accuracy: 0.7223
# Epoch 5/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6438 - accuracy: 0.7248
# Epoch 6/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6516 - accuracy: 0.7279
# Epoch 7/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.6688 - accuracy: 0.7213
# Epoch 8/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.6982 - accuracy: 0.7251
# Epoch 9/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6576 - accuracy: 0.7271
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.6375 - accuracy: 0.7282 - 488ms/epoch - 2ms/step
# Loss: 0.6374562978744507, Accuracy: 0.7281632423400879

# %% [markdown]
# Second attempt:Adding more neurons and  less layers

# %%
#Second Attempt
nn = tf.keras.models.Sequential()
nn.add(tf.keras.layers.Dense(input_dim=41, units=90, activation="relu"))
nn.add(tf.keras.layers.Dense(input_dim=30, units=30, activation="relu"))
nn.add(tf.keras.layers.Dense(input_dim=10, units=20, activation="relu"))
nn.add(tf.keras.layers.Dense(units=1, activation="linear"))
nn.summary()

# what I think it is: param / units = suceeding units + 1? except first one.
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_17 (Dense)            (None, 90)                3780
#
#  dense_18 (Dense)            (None, 30)                2730
#
#  dense_19 (Dense)            (None, 20)                620
#
#  dense_20 (Dense)            (None, 1)                 21
#
# ...
# Total params: 7151 (27.93 KB)
# Trainable params: 7151 (27.93 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.8599 - accuracy: 0.7057
# Epoch 2/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.7409 - accuracy: 0.7018
# Epoch 3/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6007 - accuracy: 0.7163
# Epoch 4/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.6024 - accuracy: 0.7198
# Epoch 5/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6326 - accuracy: 0.7005
# Epoch 6/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5986 - accuracy: 0.7265
# Epoch 7/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5724 - accuracy: 0.7282
# Epoch 8/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5736 - accuracy: 0.7245
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5715 - accuracy: 0.7285
# Epoch 10/100
# ...

# %%
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.6079 - accuracy: 0.7205 - 468ms/epoch - 2ms/step
# Loss: 0.6078738570213318, Accuracy: 0.7204664945602417

# %%
#Third Attempt
#Revised a little bit  of the original third model as well.
# Control the number of epochs
#Adding more neurons and units lowered a bit, I might find some sort of middle

nn = tf.keras.models.Sequential()
nn.add(tf.keras.layers.Dense(input_dim=41, units=80, activation="relu"))
nn.add(tf.keras.layers.Dense(input_dim=20, units=40, activation="relu"))
nn.add(tf.keras.layers.Dense(input_dim=20, units=10, activation="relu"))
nn.add(tf.keras.layers.Dense(input_dim=11, units=5, activation="sigmoid"))
nn.add(tf.keras.layers.Dense(units=1, activation="linear"))
nn.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_35 (Dense)            (None, 80)                3360
#
#  dense_36 (Dense)            (None, 40)                3240
#
#  dense_37 (Dense)            (None, 10)                410
#
#  dense_38 (Dense)            (None, 5)                 55
#
#  dense_39 (Dense)            (None, 1)                 6
#
# ...
# Total params: 7071 (27.62 KB)
# Trainable params: 7071 (27.62 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])
checkpoint =  ModelCheckpoint("best_model.hdf5", monitor='loss', verbose=1,save_best_only=True, mode='auto', period=5)
fit_model=nn.fit(X_train_scaled, y_train,
          epochs=75,
          verbose=1,
          validation_data=(X_test, y_test),
          callbacks=[checkpoint])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/75
# 804/804 [==============================] - 8s 7ms/step - loss: 8.2288 - accuracy: 0.4665 - val_loss: 8.1631 - val_accuracy: 0.4708
# Epoch 2/75
# 804/804 [==============================] - 3s 4ms/step - loss: 8.2288 - accuracy: 0.4665 - val_loss: 8.1631 - val_accuracy: 0.4708
# Epoch 3/75
# 804/804 [==============================] - 2s 2ms/step - loss: 8.2288 - accuracy: 0.4665 - val_loss: 8.1631 - val_accuracy: 0.4708
# Epoch 4/75
# 804/804 [==============================] - 2s 2ms/step - loss: 8.2288 - accuracy: 0.4665 - val_loss: 8.1631 - val_accuracy: 0.4708
# Epoch 5/75
# 794/804 [============================>.] - ETA: 0s - loss: 8.2328 - accuracy: 0.4663
# Epoch 5: loss improved from inf to 8.22876, saving model to best_model.hdf5
# ...

# %%
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 8.1631 - accuracy: 0.4708 - 464ms/epoch - 2ms/step
# Loss: 8.163082122802734, Accuracy: 0.4707871675491333

# %%
#Fourth attempt
# I had trouble importing keras_tuner and I do have it installed so not sure what's the reason.

#Here I will use less epochs, few more units, input_dim the same
nn = tf.keras.models.Sequential([
    tf.keras.layers.Dense(units=90, activation="relu", input_dim=41),
    tf.keras.layers.Dense(units=40, activation="relu"),
    tf.keras.layers.Dense(units=1, activation="sigmoid")
])

nn.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_43 (Dense)            (None, 90)                3780
#
#  dense_44 (Dense)            (None, 40)                3640
#
#  dense_45 (Dense)            (None, 1)                 41
#
# ...
# Total params: 7461 (29.14 KB)
# Trainable params: 7461 (29.14 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])
fit_model = nn.fit(X_train_scaled, y_train, epochs=80)
# Out:
# Epoch 1/80
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5689 - accuracy: 0.7201
# Epoch 2/80
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5547 - accuracy: 0.7293
# Epoch 3/80
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5529 - accuracy: 0.7297
# Epoch 4/80
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5505 - accuracy: 0.7307
# Epoch 5/80
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5501 - accuracy: 0.7326
# Epoch 6/80
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5488 - accuracy: 0.7322
# Epoch 7/80
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5478 - accuracy: 0.7309
# Epoch 8/80
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5473 - accuracy: 0.7331
# Epoch 9/80
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5465 - accuracy: 0.7339
# Epoch 10/80
# ...

# %%
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5565 - accuracy: 0.7300 - 450ms/epoch - 2ms/step
# Loss: 0.5565274357795715, Accuracy: 0.7300291657447815

# %% [markdown]
# Actually got to 73% this time.Still needs improvement.

# %%
pip install keras-tuner
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.1/129.1 kB 2.8 MB/s eta 0:00:00
# ...

# %%
# I had to install it here for it to work!
import keras_tuner as kt

# %%
#Fifth attempt
#Using fine tuner
# In class activity 22.2.04 modified code
def create_model(hp):
    nn_model = tf.keras.models.Sequential()

    # Allow kerastuner to decide which activation function to use in hidden layers
    activation = hp.Choice('activation',['relu','tanh','sigmoid'])

    # Allow kerastuner to decide number of neurons in first layer
    nn_model.add(tf.keras.layers.Dense(units=hp.Int('first_units',
        min_value=1,
        max_value=90,
        step=3), activation=activation, input_dim=41))

    # Allow kerastuner to decide number of hidden layers and neurons in hidden layers
    for i in range(hp.Int('num_layers', 1, 6)):
        nn_model.add(tf.keras.layers.Dense(units=hp.Int('units_' + str(i),
            min_value=1,
            max_value=3,
            step=3),
            activation=activation))

    nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

    # Compile the model
    nn_model.compile(loss="binary_crossentropy", optimizer='adam', metrics=["accuracy"])

    return nn_model

# %%
#Fifth attempt
#Using fine tuner
# Based on in class activity
tuner = kt.Hyperband(
    create_model,
    objective="val_accuracy",
    max_epochs=80,
    hyperband_iterations=2)

# %%
tuner.search(X_train_scaled,y_train,epochs=80,validation_data=(X_test_scaled,y_test))
# Out:
# Trial 164 Complete [00h 04m 50s]
# val_accuracy: 0.7329446077346802
#
# Best val_accuracy So Far: 0.73399418592453
# Total elapsed time: 01h 44m 41s
#
# Search: Running Trial #165
#
# Value             |Best Value So Far |Hyperparameter
# tanh              |sigmoid           |activation
# 67                |10                |first_units
# 6                 |4                 |num_layers
# 1                 |1                 |units_0
# 1                 |1                 |units_1
# 1                 |1                 |units_2
# 1                 |1                 |units_3
# 1                 |1                 |units_4
# 1                 |1                 |units_5
# 27                |27                |tuner/epochs
# 0                 |9                 |tuner/initial_epoch
# 1                 |2                 |tuner/bracket
# 0                 |1                 |tuner/round
#
# Epoch 1/27
# ...

# %%
best_hyper = tuner.get_best_hyperparameters(1)[0]
best_hyper.values
# Out:
# {'activation': 'sigmoid',
#  'first_units': 10,
#  'num_layers': 4,
#  'units_0': 1,
#  'units_1': 1,
#  'units_2': 1,
#  'units_3': 1,
#  'units_4': 1,
#  'units_5': 1,
#  'tuner/epochs': 27,
#  'tuner/initial_epoch': 9,
#  'tuner/bracket': 2,
#  'tuner/round': 1,
#  'tuner/trial_id': '0064'}

# %%
best_model = tuner.get_best_models(1)[0]
model_loss, model_accuracy = best_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5766 - accuracy: 0.7340 - 594ms/epoch - 2ms/step
# Loss: 0.5766450762748718, Accuracy: 0.73399418592453

# %%
# Export our model to HDF5 file
nn.save('AlphabetSoupCharity_Optimization.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
filepath = r"/Users/pcn08/ucb/homework/deep-learning-challenge/Module_21 Files\AlphabetSoupCharity_Optimization.h5"
nn.save(filepath, save_format='h5')
